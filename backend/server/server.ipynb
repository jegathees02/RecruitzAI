# %%
from flask import Flask, request, jsonify
from flask_cors import CORS
from IPython import get_ipython
import os
import base64
from pyngrok import ngrok
import random
import eye_tracking
import voice
import voice_output
# Out:
# 2024-01-26 18:17:01.352600: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-26 18:17:01.376221: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-26 18:17:01.630561: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-26 18:17:01.632072: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-26 18:17:02.599922: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# pip install import-ipynb
# import import_ipynb
# from "../voice" import voice.ipynb
# %run ../voice/voice.ipynb
# import sys
# sys.path.append("../voice")
# sys.path.append("../video")
# sys.path.append("../eye_track")
# from eye_track import eye_tracking as eye_main

# %%
app = Flask(__name__)
CORS(app)

# %%
# Set the path to store videos
UPLOAD_FOLDER = '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/'
app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER

# %%
def upload_video(video_data):        
   

    if video_data:
        video_name = 'uploaded_video.webm'
        video_path = os.path.join(app.config['UPLOAD_FOLDER'], video_name)
        print(video_path)
        print(video_name)
        video_data.save(video_path)  # Save the file
        
        
        
        # return result
        return jsonify({'message': 'Video uploaded successfully'}), 200
    else:
        return jsonify({'error': 'No video data provided'}), 400

# %%
def eye_track_module():
    # Run the other Jupyter notebook with the correct path
        eye_tracking_notebook_path = '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/eye_track/EyeTracking.ipynb'
        # get_ipython().run_line_magic('run', eye_tracking_notebook_path)

        result = eye_tracking.eye_tracking_method('/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/uploaded_video.webm')
        print(result)
        return result

# %%
# from backend.eye_track.eye_tracking import eye_tracking


@app.route('/upload_video_new', methods=['POST'])
def upload_frontend_video():
    try:
         # Remove the assumption of JSON data
        video_data = request.files['videoData']
        upload_video(video_data)
    except Exception as e:
        return jsonify({'error': str(e)}), 500
    
    try:
        result = eye_track_module()
    except Exception as e:
        return jsonify({'error': str(e)}), 500
    
    result_str = str(result)

    return jsonify({'message': 'Video uploaded successfully', 'result': result_str}), 200

# %%
@app.route('/get_result', methods=['GET'])
def getResult():
    try:
        video_path = '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/uploaded_video.webm'
        eye_contact = eye_tracking.check_happiness(video_path)
        eye_contact = round(eye_contact,2)
        if(eye_contact == 1) :
            with app.app_context():
                # if(eye_contact == 1):
                return jsonify({ "eye_contact": eye_contact , "boldness" : 1, "clarity" : 1, "confidence" : 1, "overall" : 1})
                # else:
                #     return jsonify({ "eye_contact": eye_contact , "boldness" : boldness, "clarity" : clarity, "confidence" : confidence, "overall" : overall})
        voice.voice_extraction_main()
        # voice_quality_analysis = voice_output.voice_quality()
        clarity = voice_output.calculate_clarity()
        boldness = voice_output.calculate_boldness()
        clarity = round(clarity,2)
        boldness = round(boldness,2)
        confidence = (eye_contact+clarity+boldness)/3
        confidence = round(confidence,2)
        overall = (eye_contact+boldness+clarity+confidence)//4
        overall = round(overall,2)
        # print("clarity :"+clarity + "confidence: "+confidence +" boldness : "+boldness +" eye_contact : "+eye_contact + "Overall : "+overall)
        # Create the JSON response within the application context
        with app.app_context():
            # if(eye_contact == 1):
            #     return jsonify({ "eye_contact": eye_contact , "boldness" : 1, "clarity" : 1, "confidence" : 1, "overall" : 1})
            # else:
            return jsonify({ "eye_contact": eye_contact , "boldness" : boldness, "clarity" : clarity, "confidence" : confidence, "overall" : overall})
    except Exception as e:
        return "Error occurred: " + str(e), 500

# %%
# if __name__ == '__main__':
#     # Start the Flask app
#     app.run()

# %%
if __name__ == '__main__':
    # Set up ngrok and expose the Flask app
    ngrok_tunnel = ngrok.connect(5000)
    print('Public URL:', ngrok_tunnel.public_url)
    app.run(host='localhost', port=5000)
# Out:
# t=2024-01-26T18:17:04+0530 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/home/jegathees5555/.config/ngrok/ngrok.yml legacy_path=/home/jegathees5555/.ngrok2/ngrok.yml
# Public URL: https://5ce3-2401-4900-634a-48b-5282-26de-edbd-7243.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit
# Average Gaze Percentage: 73.23
# 1/1 [==============================] - 0s 129ms/step
# Happiness Percentage: 11.13%
# Sadness Percentage: 88.87%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 23.77%
# Sadness Percentage: 76.23%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 30.18%
# Sadness Percentage: 69.82%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 42.19%
# Sadness Percentage: 57.81%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 45.60%
# Sadness Percentage: 54.40%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 21.56%
# Sadness Percentage: 78.44%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 49.55%
# Sadness Percentage: 50.45%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 57.66%
# Sadness Percentage: 42.34%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 68.37%
# Sadness Percentage: 31.63%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 49.47%
# Sadness Percentage: 50.53%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 78.71%
# Sadness Percentage: 21.29%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 91.94%
# Sadness Percentage: 8.06%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 96.05%
# Sadness Percentage: 3.95%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 90.80%
# Sadness Percentage: 9.20%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 95.90%
# Sadness Percentage: 4.10%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 91.83%
# Sadness Percentage: 8.17%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 85.84%
# Sadness Percentage: 14.16%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 91.97%
# Sadness Percentage: 8.03%
# 1/1 [==============================] - 0s 25ms/step
# Happiness Percentage: 68.92%
# Sadness Percentage: 31.08%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 76.81%
# Sadness Percentage: 23.19%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 41.58%
# Sadness Percentage: 58.42%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 41.27%
# Sadness Percentage: 58.73%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 61.73%
# Sadness Percentage: 38.27%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 48.07%
# Sadness Percentage: 51.93%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 57.07%
# Sadness Percentage: 42.93%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 28.21%
# Sadness Percentage: 71.79%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 14.19%
# Sadness Percentage: 85.81%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 20.73%
# Sadness Percentage: 79.27%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 18.62%
# Sadness Percentage: 81.38%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.80%
# Sadness Percentage: 79.20%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.13%
# Sadness Percentage: 79.87%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 7.25%
# Sadness Percentage: 92.75%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 18.47%
# Sadness Percentage: 81.53%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 9.86%
# Sadness Percentage: 90.14%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 53.59%
# Sadness Percentage: 46.41%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 12.19%
# Sadness Percentage: 87.81%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.89%
# Sadness Percentage: 83.11%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 14.58%
# Sadness Percentage: 85.42%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.88%
# Sadness Percentage: 83.12%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 24.39%
# Sadness Percentage: 75.61%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 14.61%
# Sadness Percentage: 85.39%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 10.95%
# Sadness Percentage: 89.05%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 10.18%
# Sadness Percentage: 89.82%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 24.45%
# Sadness Percentage: 75.55%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 26.39%
# Sadness Percentage: 73.61%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 30.70%
# Sadness Percentage: 69.30%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 10.59%
# Sadness Percentage: 89.41%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 20.14%
# Sadness Percentage: 79.86%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 14.97%
# Sadness Percentage: 85.03%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 27.06%
# Sadness Percentage: 72.94%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 31.01%
# Sadness Percentage: 68.99%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 20.32%
# Sadness Percentage: 79.68%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 19.30%
# Sadness Percentage: 80.70%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 15.76%
# Sadness Percentage: 84.24%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.19%
# Sadness Percentage: 82.81%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 19.80%
# Sadness Percentage: 80.20%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 21.94%
# Sadness Percentage: 78.06%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 5.68%
# Sadness Percentage: 94.32%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 23.52%
# Sadness Percentage: 76.48%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 6.86%
# Sadness Percentage: 93.14%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 32.33%
# Sadness Percentage: 67.67%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.57%
# Sadness Percentage: 83.43%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 10.21%
# Sadness Percentage: 89.79%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.78%
# Sadness Percentage: 79.22%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 7.56%
# Sadness Percentage: 92.44%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 42.12%
# Sadness Percentage: 57.88%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 11.49%
# Sadness Percentage: 88.51%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 10.28%
# Sadness Percentage: 89.72%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 9.59%
# Sadness Percentage: 90.41%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.46%
# Sadness Percentage: 82.54%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 23.99%
# Sadness Percentage: 76.01%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 21.06%
# Sadness Percentage: 78.94%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 5.81%
# Sadness Percentage: 94.19%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 14.18%
# Sadness Percentage: 85.82%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.82%
# Sadness Percentage: 83.18%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 29.99%
# Sadness Percentage: 70.01%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 18.60%
# Sadness Percentage: 81.40%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 5.76%
# Sadness Percentage: 94.24%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 14.88%
# Sadness Percentage: 85.12%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 12.37%
# Sadness Percentage: 87.63%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 44.70%
# Sadness Percentage: 55.30%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 13.70%
# Sadness Percentage: 86.30%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 20.60%
# Sadness Percentage: 79.40%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 10.43%
# Sadness Percentage: 89.57%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 25.00%
# Sadness Percentage: 75.00%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 23.65%
# Sadness Percentage: 76.35%
# 1/1 [==============================] - 0s 21ms/step
# Happiness Percentage: 25.98%
# Sadness Percentage: 74.02%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 19.83%
# Sadness Percentage: 80.17%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 13.53%
# Sadness Percentage: 86.47%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 28.70%
# Sadness Percentage: 71.30%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 24.53%
# Sadness Percentage: 75.47%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 35.13%
# Sadness Percentage: 64.87%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 10.81%
# Sadness Percentage: 89.19%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 20.26%
# Sadness Percentage: 79.74%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 13.06%
# Sadness Percentage: 86.94%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 29.55%
# Sadness Percentage: 70.45%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.85%
# Sadness Percentage: 83.15%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.07%
# Sadness Percentage: 82.93%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 8.74%
# Sadness Percentage: 91.26%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.33%
# Sadness Percentage: 82.67%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 14.89%
# Sadness Percentage: 85.11%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 19.72%
# Sadness Percentage: 80.28%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 19.77%
# Sadness Percentage: 80.23%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 8.18%
# Sadness Percentage: 91.82%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 24.59%
# Sadness Percentage: 75.41%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 12.02%
# Sadness Percentage: 87.98%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 35.23%
# Sadness Percentage: 64.77%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 10.06%
# Sadness Percentage: 89.94%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 14.11%
# Sadness Percentage: 85.89%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 11.33%
# Sadness Percentage: 88.67%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 7.93%
# Sadness Percentage: 92.07%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 38.66%
# Sadness Percentage: 61.34%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 13.99%
# Sadness Percentage: 86.01%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 12.82%
# Sadness Percentage: 87.18%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 8.34%
# Sadness Percentage: 91.66%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.03%
# Sadness Percentage: 82.97%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 32.12%
# Sadness Percentage: 67.88%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 26.27%
# Sadness Percentage: 73.73%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 4.91%
# Sadness Percentage: 95.09%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 15.84%
# Sadness Percentage: 84.16%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 15.78%
# Sadness Percentage: 84.22%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 45.38%
# Sadness Percentage: 54.62%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 19.23%
# Sadness Percentage: 80.77%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 9.78%
# Sadness Percentage: 90.22%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.36%
# Sadness Percentage: 82.64%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 17.43%
# Sadness Percentage: 82.57%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 56.17%
# Sadness Percentage: 43.83%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 19.66%
# Sadness Percentage: 80.34%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.91%
# Sadness Percentage: 79.09%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 11.00%
# Sadness Percentage: 89.00%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 44.32%
# Sadness Percentage: 55.68%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 33.43%
# Sadness Percentage: 66.57%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 34.32%
# Sadness Percentage: 65.68%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 14.07%
# Sadness Percentage: 85.93%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 17.36%
# Sadness Percentage: 82.64%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 21.44%
# Sadness Percentage: 78.56%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 30.62%
# Sadness Percentage: 69.38%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 30.40%
# Sadness Percentage: 69.60%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 13.31%
# Sadness Percentage: 86.69%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.49%
# Sadness Percentage: 82.51%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 13.87%
# Sadness Percentage: 86.13%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 33.96%
# Sadness Percentage: 66.04%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 21.45%
# Sadness Percentage: 78.55%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 33.98%
# Sadness Percentage: 66.02%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 7.49%
# Sadness Percentage: 92.51%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 32.88%
# Sadness Percentage: 67.12%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 16.24%
# Sadness Percentage: 83.76%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 27.49%
# Sadness Percentage: 72.51%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 31.38%
# Sadness Percentage: 68.62%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 11.06%
# Sadness Percentage: 88.94%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 31.83%
# Sadness Percentage: 68.17%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.79%
# Sadness Percentage: 83.21%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 55.39%
# Sadness Percentage: 44.61%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 24.45%
# Sadness Percentage: 75.55%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 28.64%
# Sadness Percentage: 71.36%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 24.22%
# Sadness Percentage: 75.78%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 38.40%
# Sadness Percentage: 61.60%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 53.62%
# Sadness Percentage: 46.38%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 46.26%
# Sadness Percentage: 53.74%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 27.48%
# Sadness Percentage: 72.52%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 44.19%
# Sadness Percentage: 55.81%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 49.96%
# Sadness Percentage: 50.04%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 77.71%
# Sadness Percentage: 22.29%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 68.16%
# Sadness Percentage: 31.84%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 51.99%
# Sadness Percentage: 48.01%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 63.67%
# Sadness Percentage: 36.33%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 66.16%
# Sadness Percentage: 33.84%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 90.01%
# Sadness Percentage: 9.99%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 70.90%
# Sadness Percentage: 29.10%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 85.32%
# Sadness Percentage: 14.68%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 84.87%
# Sadness Percentage: 15.13%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 93.83%
# Sadness Percentage: 6.17%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 89.62%
# Sadness Percentage: 10.38%
# 1/1 [==============================] - 0s 29ms/step
# Happiness Percentage: 90.09%
# Sadness Percentage: 9.91%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 90.51%
# Sadness Percentage: 9.49%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 93.72%
# Sadness Percentage: 6.28%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 97.76%
# Sadness Percentage: 2.24%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 90.17%
# Sadness Percentage: 9.83%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 93.60%
# Sadness Percentage: 6.40%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 70.43%
# Sadness Percentage: 29.57%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 89.53%
# Sadness Percentage: 10.47%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 43.30%
# Sadness Percentage: 56.70%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 4.24%
# Sadness Percentage: 95.76%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 28.80%
# Sadness Percentage: 71.20%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 94.33%
# Sadness Percentage: 5.67%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 99.49%
# Sadness Percentage: 0.51%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 99.69%
# Sadness Percentage: 0.31%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 96.29%
# Sadness Percentage: 3.71%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 96.33%
# Sadness Percentage: 3.67%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 75.68%
# Sadness Percentage: 24.32%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 12.13%
# Sadness Percentage: 87.87%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 5.03%
# Sadness Percentage: 94.97%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.26%
# Sadness Percentage: 97.74%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 19.72%
# Sadness Percentage: 80.28%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 29.69%
# Sadness Percentage: 70.31%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 76.85%
# Sadness Percentage: 23.15%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 73.75%
# Sadness Percentage: 26.25%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 81.42%
# Sadness Percentage: 18.58%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 92.93%
# Sadness Percentage: 7.07%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 78.29%
# Sadness Percentage: 21.71%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 79.97%
# Sadness Percentage: 20.03%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 96.23%
# Sadness Percentage: 3.77%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 99.39%
# Sadness Percentage: 0.61%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 99.90%
# Sadness Percentage: 0.10%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 99.96%
# Sadness Percentage: 0.04%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 99.56%
# Sadness Percentage: 0.44%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 99.47%
# Sadness Percentage: 0.53%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 90.43%
# Sadness Percentage: 9.57%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 94.50%
# Sadness Percentage: 5.50%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 29.57%
# Sadness Percentage: 70.43%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.57%
# Sadness Percentage: 97.43%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 9.92%
# Sadness Percentage: 90.08%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 13.56%
# Sadness Percentage: 86.44%
# 1/1 [==============================] - 0s 23ms/step
# Happiness Percentage: 15.36%
# Sadness Percentage: 84.64%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 9.77%
# Sadness Percentage: 90.23%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 22.66%
# Sadness Percentage: 77.34%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 14.25%
# Sadness Percentage: 85.75%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 27.53%
# Sadness Percentage: 72.47%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 16.10%
# Sadness Percentage: 83.90%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 40.99%
# Sadness Percentage: 59.01%
# 1/1 [==============================] - 0s 23ms/step
# Happiness Percentage: 17.23%
# Sadness Percentage: 82.77%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 31.69%
# Sadness Percentage: 68.31%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 18.08%
# Sadness Percentage: 81.92%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 3.55%
# Sadness Percentage: 96.45%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 1.69%
# Sadness Percentage: 98.31%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 1.37%
# Sadness Percentage: 98.63%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.46%
# Sadness Percentage: 97.54%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 3.91%
# Sadness Percentage: 96.09%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 30.23%
# Sadness Percentage: 69.77%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 26.45%
# Sadness Percentage: 73.55%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 45.50%
# Sadness Percentage: 54.50%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.58%
# Sadness Percentage: 83.42%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 21.87%
# Sadness Percentage: 78.13%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 23.80%
# Sadness Percentage: 76.20%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 6.38%
# Sadness Percentage: 93.62%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 5.95%
# Sadness Percentage: 94.05%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 1.54%
# Sadness Percentage: 98.46%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.91%
# Sadness Percentage: 97.09%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 3.37%
# Sadness Percentage: 96.63%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 3.55%
# Sadness Percentage: 96.45%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 1.75%
# Sadness Percentage: 98.25%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.45%
# Sadness Percentage: 97.55%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 2.63%
# Sadness Percentage: 97.37%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 6.30%
# Sadness Percentage: 93.70%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 2.60%
# Sadness Percentage: 97.40%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 2.28%
# Sadness Percentage: 97.72%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.04%
# Sadness Percentage: 97.96%
# 1/1 [==============================] - 0s 22ms/step
# Happiness Percentage: 2.22%
# Sadness Percentage: 97.78%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 3.35%
# Sadness Percentage: 96.65%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.85%
# Sadness Percentage: 97.15%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 2.51%
# Sadness Percentage: 97.49%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 0.90%
# Sadness Percentage: 99.10%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 4.17%
# Sadness Percentage: 95.83%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 1.88%
# Sadness Percentage: 98.12%
# 1/1 [==============================] - 0s 20ms/step
# Happiness Percentage: 7.69%
# Sadness Percentage: 92.31%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 1.54%
# Sadness Percentage: 98.46%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 1.84%
# Sadness Percentage: 98.16%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 2.28%
# Sadness Percentage: 97.72%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 2.86%
# Sadness Percentage: 97.14%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 6.11%
# Sadness Percentage: 93.89%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 1.41%
# Sadness Percentage: 98.59%
# 1/1 [==============================] - 0s 19ms/step
# Happiness Percentage: 1.63%
# Sadness Percentage: 98.37%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 1.12%
# Sadness Percentage: 98.88%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 2.56%
# Sadness Percentage: 97.44%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 1.41%
# Sadness Percentage: 98.59%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 2.60%
# Sadness Percentage: 97.40%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 0.78%
# Sadness Percentage: 99.22%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 1.39%
# Sadness Percentage: 98.61%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 1.63%
# Sadness Percentage: 98.37%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 1.76%
# Sadness Percentage: 98.24%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 1.02%
# Sadness Percentage: 98.98%
# Average Happiness Percentage: 31.48%
# Average Sadness Percentage: 68.52%
# 73.23182574996095
# Average Result: 52.36
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/uploaded_video.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
#   Stream #0:1(eng): Video: vp8, yuv420p(progressive), 640x480, SAR 1:1 DAR 4:3, 250 tbr, 1k tbn, 1k tbc (default)
#     Metadata:
#       alpha_mode      : 1
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/output.mp3':
#   Metadata:
#     TSSE            : Lavf58.76.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, mono, fltp (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libmp3lame
# size=      72kB time=00:00:09.16 bitrate=  64.5kbits/s speed= 110x
# video:0kB audio:72kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.321452%
# 127.0.0.1 - - [26/Jan/2024 18:17:28] "GET /get_result HTTP/1.1" 200 -
# Average Gaze Percentage: 73.26
# 1/1 [==============================] - 0s 30ms/step
# Happiness Percentage: 11.13%
# Sadness Percentage: 88.87%
# 1/1 [==============================] - 0s 26ms/step
# Happiness Percentage: 23.77%
# Sadness Percentage: 76.23%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 30.18%
# Sadness Percentage: 69.82%
# 1/1 [==============================] - 0s 24ms/step
# Happiness Percentage: 42.19%
# Sadness Percentage: 57.81%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 45.60%
# Sadness Percentage: 54.40%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 21.56%
# Sadness Percentage: 78.44%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 49.55%
# Sadness Percentage: 50.45%
# 1/1 [==============================] - 0s 22ms/step
# Happiness Percentage: 57.66%
# Sadness Percentage: 42.34%
# 1/1 [==============================] - 0s 22ms/step
# Happiness Percentage: 68.37%
# Sadness Percentage: 31.63%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 49.47%
# Sadness Percentage: 50.53%
# 1/1 [==============================] - 0s 23ms/step
# Happiness Percentage: 78.71%
# Sadness Percentage: 21.29%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 91.94%
# Sadness Percentage: 8.06%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 96.05%
# Sadness Percentage: 3.95%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 90.80%
# Sadness Percentage: 9.20%
# 1/1 [==============================] - 0s 23ms/step
# Happiness Percentage: 95.90%
# Sadness Percentage: 4.10%
# 1/1 [==============================] - 0s 23ms/step
# Happiness Percentage: 91.83%
# Sadness Percentage: 8.17%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 85.84%
# Sadness Percentage: 14.16%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 91.97%
# Sadness Percentage: 8.03%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 68.92%
# Sadness Percentage: 31.08%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 76.81%
# Sadness Percentage: 23.19%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 41.58%
# Sadness Percentage: 58.42%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 41.27%
# Sadness Percentage: 58.73%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 61.73%
# Sadness Percentage: 38.27%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 48.07%
# Sadness Percentage: 51.93%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 57.07%
# Sadness Percentage: 42.93%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 28.21%
# Sadness Percentage: 71.79%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 14.19%
# Sadness Percentage: 85.81%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.73%
# Sadness Percentage: 79.27%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 18.62%
# Sadness Percentage: 81.38%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 20.80%
# Sadness Percentage: 79.20%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.13%
# Sadness Percentage: 79.87%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 7.25%
# Sadness Percentage: 92.75%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 18.47%
# Sadness Percentage: 81.53%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 9.86%
# Sadness Percentage: 90.14%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 53.59%
# Sadness Percentage: 46.41%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 12.19%
# Sadness Percentage: 87.81%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 16.89%
# Sadness Percentage: 83.11%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 14.58%
# Sadness Percentage: 85.42%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 16.88%
# Sadness Percentage: 83.12%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 24.39%
# Sadness Percentage: 75.61%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 14.61%
# Sadness Percentage: 85.39%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 10.95%
# Sadness Percentage: 89.05%
# 1/1 [==============================] - 0s 22ms/step
# Happiness Percentage: 10.18%
# Sadness Percentage: 89.82%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 24.45%
# Sadness Percentage: 75.55%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 26.39%
# Sadness Percentage: 73.61%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 30.70%
# Sadness Percentage: 69.30%
# 1/1 [==============================] - 0s 30ms/step
# Happiness Percentage: 10.59%
# Sadness Percentage: 89.41%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 20.14%
# Sadness Percentage: 79.86%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 14.97%
# Sadness Percentage: 85.03%
# 1/1 [==============================] - 0s 21ms/step
# Happiness Percentage: 27.06%
# Sadness Percentage: 72.94%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 31.01%
# Sadness Percentage: 68.99%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 20.32%
# Sadness Percentage: 79.68%
# 1/1 [==============================] - 0s 20ms/step
# Happiness Percentage: 19.30%
# Sadness Percentage: 80.70%
# 1/1 [==============================] - 0s 21ms/step
# Happiness Percentage: 15.76%
# Sadness Percentage: 84.24%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 17.19%
# Sadness Percentage: 82.81%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 19.80%
# Sadness Percentage: 80.20%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 21.94%
# Sadness Percentage: 78.06%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 5.68%
# Sadness Percentage: 94.32%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 23.52%
# Sadness Percentage: 76.48%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 6.86%
# Sadness Percentage: 93.14%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 32.33%
# Sadness Percentage: 67.67%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 16.57%
# Sadness Percentage: 83.43%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 10.21%
# Sadness Percentage: 89.79%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 20.78%
# Sadness Percentage: 79.22%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 7.56%
# Sadness Percentage: 92.44%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 42.12%
# Sadness Percentage: 57.88%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 11.49%
# Sadness Percentage: 88.51%
# 1/1 [==============================] - 0s 19ms/step
# Happiness Percentage: 10.28%
# Sadness Percentage: 89.72%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 9.59%
# Sadness Percentage: 90.41%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 17.46%
# Sadness Percentage: 82.54%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 23.99%
# Sadness Percentage: 76.01%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 21.06%
# Sadness Percentage: 78.94%
# 1/1 [==============================] - 0s 19ms/step
# Happiness Percentage: 5.81%
# Sadness Percentage: 94.19%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 14.18%
# Sadness Percentage: 85.82%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 16.82%
# Sadness Percentage: 83.18%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 29.99%
# Sadness Percentage: 70.01%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 18.60%
# Sadness Percentage: 81.40%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 5.76%
# Sadness Percentage: 94.24%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 14.88%
# Sadness Percentage: 85.12%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 12.37%
# Sadness Percentage: 87.63%
# 1/1 [==============================] - 0s 19ms/step
# Happiness Percentage: 44.70%
# Sadness Percentage: 55.30%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 13.70%
# Sadness Percentage: 86.30%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.60%
# Sadness Percentage: 79.40%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 10.43%
# Sadness Percentage: 89.57%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 25.00%
# Sadness Percentage: 75.00%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 23.65%
# Sadness Percentage: 76.35%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 25.98%
# Sadness Percentage: 74.02%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 19.83%
# Sadness Percentage: 80.17%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 13.53%
# Sadness Percentage: 86.47%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 28.70%
# Sadness Percentage: 71.30%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 24.53%
# Sadness Percentage: 75.47%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 35.13%
# Sadness Percentage: 64.87%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 10.81%
# Sadness Percentage: 89.19%
# 1/1 [==============================] - 0s 20ms/step
# Happiness Percentage: 20.26%
# Sadness Percentage: 79.74%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 13.06%
# Sadness Percentage: 86.94%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 29.55%
# Sadness Percentage: 70.45%
# 1/1 [==============================] - 0s 20ms/step
# Happiness Percentage: 16.85%
# Sadness Percentage: 83.15%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 17.07%
# Sadness Percentage: 82.93%
# 1/1 [==============================] - 0s 28ms/step
# Happiness Percentage: 8.74%
# Sadness Percentage: 91.26%
# 1/1 [==============================] - 0s 21ms/step
# Happiness Percentage: 17.33%
# Sadness Percentage: 82.67%
# 1/1 [==============================] - 0s 22ms/step
# Happiness Percentage: 14.89%
# Sadness Percentage: 85.11%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 19.72%
# Sadness Percentage: 80.28%
# 1/1 [==============================] - 0s 28ms/step
# Happiness Percentage: 19.77%
# Sadness Percentage: 80.23%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 8.18%
# Sadness Percentage: 91.82%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 24.59%
# Sadness Percentage: 75.41%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 12.02%
# Sadness Percentage: 87.98%
# 1/1 [==============================] - 0s 17ms/step
# Happiness Percentage: 35.23%
# Sadness Percentage: 64.77%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 10.06%
# Sadness Percentage: 89.94%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 14.11%
# Sadness Percentage: 85.89%
# 1/1 [==============================] - 0s 26ms/step
# Happiness Percentage: 11.33%
# Sadness Percentage: 88.67%
# 1/1 [==============================] - 0s 36ms/step
# Happiness Percentage: 7.93%
# Sadness Percentage: 92.07%
# 1/1 [==============================] - 0s 18ms/step
# Happiness Percentage: 38.66%
# Sadness Percentage: 61.34%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 13.99%
# Sadness Percentage: 86.01%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 12.82%
# Sadness Percentage: 87.18%
# 1/1 [==============================] - 0s 21ms/step
# Happiness Percentage: 8.34%
# Sadness Percentage: 91.66%
# 1/1 [==============================] - 0s 19ms/step
# Happiness Percentage: 17.03%
# Sadness Percentage: 82.97%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 32.12%
# Sadness Percentage: 67.88%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 26.27%
# Sadness Percentage: 73.73%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 4.91%
# Sadness Percentage: 95.09%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 15.84%
# Sadness Percentage: 84.16%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 15.78%
# Sadness Percentage: 84.22%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 45.38%
# Sadness Percentage: 54.62%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 19.23%
# Sadness Percentage: 80.77%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 9.78%
# Sadness Percentage: 90.22%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 17.36%
# Sadness Percentage: 82.64%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 17.43%
# Sadness Percentage: 82.57%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 56.17%
# Sadness Percentage: 43.83%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 19.66%
# Sadness Percentage: 80.34%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 20.91%
# Sadness Percentage: 79.09%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 11.00%
# Sadness Percentage: 89.00%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 44.32%
# Sadness Percentage: 55.68%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 33.43%
# Sadness Percentage: 66.57%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 34.32%
# Sadness Percentage: 65.68%
# 1/1 [==============================] - 0s 16ms/step
# Happiness Percentage: 14.07%
# Sadness Percentage: 85.93%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 17.36%
# Sadness Percentage: 82.64%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 21.44%
# Sadness Percentage: 78.56%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 30.62%
# Sadness Percentage: 69.38%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 30.40%
# Sadness Percentage: 69.60%
# 1/1 [==============================] - 0s 15ms/step
# Happiness Percentage: 13.31%
# Sadness Percentage: 86.69%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 17.49%
# Sadness Percentage: 82.51%
# 1/1 [==============================] - 0s 13ms/step
# Happiness Percentage: 13.87%
# Sadness Percentage: 86.13%
# 1/1 [==============================] - 0s 14ms/step
# Happiness Percentage: 33.96%
# Sadness Percentage: 66.04%
# ...
# Sadness Percentage: 95.83%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 76.85%
# Sadness Percentage: 23.15%
# 1/1 [==============================] - 0s 44ms/step
# Happiness Percentage: 1.88%
# Sadness Percentage: 98.12%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 73.75%
# Sadness Percentage: 26.25%
# 1/1 [==============================] - 0s 41ms/step
# Happiness Percentage: 7.69%
# Sadness Percentage: 92.31%
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# Happiness Percentage: 81.42%
# Sadness Percentage: 18.58%
# Happiness Percentage: 1.54%
# Sadness Percentage: 98.46%
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# Happiness Percentage: 92.93%
# Sadness Percentage: 7.07%
# Happiness Percentage: 1.84%
# Sadness Percentage: 98.16%
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# Happiness Percentage: 2.28%
# Sadness Percentage: 97.72%
# Happiness Percentage: 78.29%
# Sadness Percentage: 21.71%
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - ETA: 0sHappiness Percentage: 2.86%
# Sadness Percentage: 97.14%
# 1/1 [==============================] - 0s 41ms/step
# Happiness Percentage: 79.97%
# Sadness Percentage: 20.03%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 6.11%
# Sadness Percentage: 93.89%
# 1/1 [==============================] - 0s 56ms/step
# Happiness Percentage: 96.23%
# Sadness Percentage: 3.77%
# 1/1 [==============================] - 0s 45ms/step
# Happiness Percentage: 1.41%
# Sadness Percentage: 98.59%
# 1/1 [==============================] - 0s 51ms/step
# Happiness Percentage: 99.39%
# Sadness Percentage: 0.61%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 1.63%
# Sadness Percentage: 98.37%
# 1/1 [==============================] - 0s 49ms/step
# Happiness Percentage: 99.90%
# Sadness Percentage: 0.10%
# 1/1 [==============================] - 0s 41ms/step
# Happiness Percentage: 1.12%
# Sadness Percentage: 98.88%
# 1/1 [==============================] - 0s 51ms/step
# Happiness Percentage: 99.96%
# Sadness Percentage: 0.04%
# 1/1 [==============================] - 0s 60ms/step
# Happiness Percentage: 2.56%
# Sadness Percentage: 97.44%
# 1/1 [==============================] - 0s 58ms/step
# Happiness Percentage: 99.56%
# Sadness Percentage: 0.44%
# 1/1 [==============================] - 0s 46ms/step
# Happiness Percentage: 1.41%
# Sadness Percentage: 98.59%
# 1/1 [==============================] - 0s 47ms/step
# Happiness Percentage: 99.47%
# Sadness Percentage: 0.53%
# 1/1 [==============================] - 0s 56ms/step
# Happiness Percentage: 2.60%
# Sadness Percentage: 97.40%
# 1/1 [==============================] - 0s 49ms/step
# Happiness Percentage: 90.43%
# Sadness Percentage: 9.57%
# 1/1 [==============================] - 0s 79ms/step
# Happiness Percentage: 0.78%
# Sadness Percentage: 99.22%
# 1/1 [==============================] - 0s 48ms/step
# Happiness Percentage: 94.50%
# Sadness Percentage: 5.50%
# 1/1 [==============================] - 0s 64ms/step
# Happiness Percentage: 1.39%
# Sadness Percentage: 98.61%
# 1/1 [==============================] - 0s 61ms/step
# Happiness Percentage: 29.57%
# Sadness Percentage: 70.43%
# 1/1 [==============================] - 0s 46ms/step
# Happiness Percentage: 1.63%
# Sadness Percentage: 98.37%
# 1/1 [==============================] - 0s 44ms/step
# Happiness Percentage: 2.57%
# Sadness Percentage: 97.43%
# 1/1 [==============================] - 0s 60ms/step
# Happiness Percentage: 1.76%
# Sadness Percentage: 98.24%
# 1/1 [==============================] - 0s 45ms/step
# Happiness Percentage: 9.92%
# Sadness Percentage: 90.08%
# 1/1 [==============================] - 0s 49ms/step
# Happiness Percentage: 1.02%
# Sadness Percentage: 98.98%
# Average Happiness Percentage: 31.48%
# Average Sadness Percentage: 68.52%
# 73.33565748884304
# Average Result: 52.41
# 1/1 [==============================] - 0s 45ms/step
# Happiness Percentage: 13.56%
# Sadness Percentage: 86.44%
# 1/1 [==============================] - 0s 41ms/step
# Happiness Percentage: 15.36%
# Sadness Percentage: 84.64%
# 1/1 [==============================] - 0s 44ms/step
# Happiness Percentage: 9.77%
# Sadness Percentage: 90.23%
# 1/1 [==============================] - 0s 52ms/step
# Happiness Percentage: 22.66%
# Sadness Percentage: 77.34%
# 1/1 [==============================] - 0s 49ms/step
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/uploaded_video.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
#   Stream #0:1(eng): Video: vp8, yuv420p(progressive), 640x480, SAR 1:1 DAR 4:3, 250 tbr, 1k tbn, 1k tbc (default)
#     Metadata:
#       alpha_mode      : 1
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/output.mp3':
#   Metadata:
#     TSSE            : Lavf58.76.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, mono, fltp (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libmp3lame
# size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# Happiness Percentage: 14.25%
# Sadness Percentage: 85.75%
# 1/1 [==============================] - 0s 49ms/step
# Happiness Percentage: 27.53%
# Sadness Percentage: 72.47%
# 1/1 [==============================] - 0s 44ms/step
# size=      72kB time=00:00:09.16 bitrate=  64.5kbits/s speed=36.7x
# video:0kB audio:72kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.321452%
# Happiness Percentage: 16.10%
# Sadness Percentage: 83.90%
# 127.0.0.1 - - [26/Jan/2024 18:23:13] "GET /get_result HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 52ms/step
# Happiness Percentage: 40.99%
# Sadness Percentage: 59.01%
# 1/1 [==============================] - 0s 42ms/step
# Happiness Percentage: 17.23%
# Sadness Percentage: 82.77%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 31.69%
# Sadness Percentage: 68.31%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 18.08%
# Sadness Percentage: 81.92%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 3.55%
# Sadness Percentage: 96.45%
# 1/1 [==============================] - 0s 45ms/step
# Happiness Percentage: 1.69%
# Sadness Percentage: 98.31%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 1.37%
# Sadness Percentage: 98.63%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 2.46%
# Sadness Percentage: 97.54%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 3.91%
# Sadness Percentage: 96.09%
# 1/1 [==============================] - 0s 43ms/step
# Happiness Percentage: 30.23%
# Sadness Percentage: 69.77%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 26.45%
# Sadness Percentage: 73.55%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 45.50%
# Sadness Percentage: 54.50%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 16.58%
# Sadness Percentage: 83.42%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 21.87%
# Sadness Percentage: 78.13%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 23.80%
# Sadness Percentage: 76.20%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 6.38%
# Sadness Percentage: 93.62%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 5.95%
# Sadness Percentage: 94.05%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 1.54%
# Sadness Percentage: 98.46%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 2.91%
# Sadness Percentage: 97.09%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 3.37%
# Sadness Percentage: 96.63%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 3.55%
# Sadness Percentage: 96.45%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 1.75%
# Sadness Percentage: 98.25%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 2.45%
# Sadness Percentage: 97.55%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 2.63%
# Sadness Percentage: 97.37%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 6.30%
# Sadness Percentage: 93.70%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 2.60%
# Sadness Percentage: 97.40%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 2.28%
# Sadness Percentage: 97.72%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 2.04%
# Sadness Percentage: 97.96%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 2.22%
# Sadness Percentage: 97.78%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 3.35%
# Sadness Percentage: 96.65%
# 1/1 [==============================] - 0s 35ms/step
# Happiness Percentage: 2.85%
# Sadness Percentage: 97.15%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 2.51%
# Sadness Percentage: 97.49%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 0.90%
# Sadness Percentage: 99.10%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 4.17%
# Sadness Percentage: 95.83%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 1.88%
# Sadness Percentage: 98.12%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 7.69%
# Sadness Percentage: 92.31%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 1.54%
# Sadness Percentage: 98.46%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 1.84%
# Sadness Percentage: 98.16%
# 1/1 [==============================] - 0s 40ms/step
# Happiness Percentage: 2.28%
# Sadness Percentage: 97.72%
# 1/1 [==============================] - 0s 49ms/step
# Happiness Percentage: 2.86%
# Sadness Percentage: 97.14%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 6.11%
# Sadness Percentage: 93.89%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 1.41%
# Sadness Percentage: 98.59%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 1.63%
# Sadness Percentage: 98.37%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 1.12%
# Sadness Percentage: 98.88%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 2.56%
# Sadness Percentage: 97.44%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 1.41%
# Sadness Percentage: 98.59%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 2.60%
# Sadness Percentage: 97.40%
# 1/1 [==============================] - 0s 38ms/step
# Happiness Percentage: 0.78%
# Sadness Percentage: 99.22%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 1.39%
# Sadness Percentage: 98.61%
# 1/1 [==============================] - 0s 37ms/step
# Happiness Percentage: 1.63%
# Sadness Percentage: 98.37%
# 1/1 [==============================] - 0s 44ms/step
# Happiness Percentage: 1.76%
# Sadness Percentage: 98.24%
# 1/1 [==============================] - 0s 39ms/step
# Happiness Percentage: 1.02%
# Sadness Percentage: 98.98%
# Average Happiness Percentage: 31.48%
# Average Sadness Percentage: 68.52%
# 73.09841240431363
# Average Result: 52.29
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/uploaded_video.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
#   Stream #0:1(eng): Video: vp8, yuv420p(progressive), 640x480, SAR 1:1 DAR 4:3, 250 tbr, 1k tbn, 1k tbc (default)
#     Metadata:
#       alpha_mode      : 1
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/home/jegathees5555/Documents/projects/AI_Interview_recruitz/backend/server/output.mp3':
#   Metadata:
#     TSSE            : Lavf58.76.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, mono, fltp (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libmp3lame
# size=      72kB time=00:00:09.16 bitrate=  64.5kbits/s speed=40.9x
# video:0kB audio:72kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.321452%
# 127.0.0.1 - - [26/Jan/2024 18:23:20] "GET /get_result HTTP/1.1" 200 -
